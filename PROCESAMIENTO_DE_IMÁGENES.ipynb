# %% [markdown]
# <a href="https://colab.research.google.com/github/ISRAEL-MP/Practica0_Comentario_codigo_-limpio/blob/main/PROCESAMIENTO_DE_IM%C3%81GENES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Imagen/Sin título.jpg")

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
imagen=cv2.imread("/content/drive/MyDrive/Imagen/Sin título.jpg")
plt.imshow(imagen)

# %%
imagen=cv2.imread("/content/drive/MyDrive/Imagen/Sin título.jpg")
cv2.imwrite('deepgris.png',imagen)
# Out:
# True

# %%
import cv2
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/Imagen/Sin título.jpg"
img = cv2.imread(path)
plt.imshow(img)

# %%
import cv2
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/Imagen/Sin título.jpg"
img = cv2.imread(path)
im_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(im_rgb)

# %%
pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

img = "/content/drive/MyDrive/Imagen/Sin título.jpg"
img = cv2.imread(img) # reads image
plt.imshow(img)

# %%
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/Imagen/Sin título.jpg"
img = cv2.imread(path)

import cv2
img = cv2.imread(path)
cv2_imshow(img)
cv2.imwrite('output.jpg',img)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=RGB size=764x424 at 0x7F7989A72260>
# -1

# %%
import cv2
imagen=cv2.imread("/content/drive/MyDrive/Imagen/Sin título.jpg")
cv2.imwrite('imagen.png', imagen)
# Out:
# True

# %%
resized_image = cv2.resize(img, (500,300))

# Colab users: 
cv2_imshow(resized_image)

# Jupyter Notebook users:
# cv2.imshow(“Penguins”, resized_image)
 
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=500x300 at 0x7F7989A72260>

# %%
# Converting color image to grayscale image
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gris_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
yuv_img = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)
y,u,v = cv2.split(yuv_img)
cv2_imshow(gris_img)

# Y luminancia Y=0.2992+0.587G+0.114B
# Showing the converted image

# Colab users:
cv2_imshow(gray_img)
cv2_imshow(y)
cv2_imshow(u)

# Jupyter Notebook users:
# cv2_imshow("Converted Image",gray_img)

# waiting for key event
cv2.waitKey(0)

# destroying all windows
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=764x424 at 0x7F7989A72AA0>
# <PIL.Image.Image image mode=L size=764x424 at 0x7F7989A73610>
# <PIL.Image.Image image mode=L size=764x424 at 0x7F7989A72AA0>
# <PIL.Image.Image image mode=L size=764x424 at 0x7F79BC13ECE0>

# %%
import cv2
import numpy as np
img = "/content/drive/MyDrive/Imagen/Sin título.jpg"
img = cv2.imread(img) # reads image
rows,cols = img.shape[:2]
M = np.float32([[1,0,210],[0,1,20]])
des = cv2.warpAffine(img,M,(cols,rows))
cv2_imshow(des)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=764x424 at 0x7F79BC13FD90>

# %%
import cv2
import numpy as np
img = "/content/drive/MyDrive/Imagen/Sin título.jpg"
img = cv2.imread(img) # reads image
rows,cols = img.shape[:2]
M = cv2.getRotationMatrix2D((cols,rows),20,1)
dst = cv2.warpAffine(img,M,(cols,rows))
cv2_imshow(dst)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=RGB size=764x424 at 0x7F7989A722C0>
# -1

# %%
import IPython
js_code = '''
document.querySelector("#output-area").appendChild(document.createTextNode("hello world!"));
'''
display(IPython.display.Javascript(js_code))

# %%
import IPython
from google.colab import output

display(IPython.display.Javascript('''
  window.someValue = new Promise(resolve => {
    setTimeout(() => {
      resolve("hello world!");
    }, 100);
  });
'''))


value = output.eval_js('someValue');
value
# Out:
# 'hello world!'

# %%
import IPython
from google.colab import output

def Concat(a, b):
  # Use display.JSON to transfer a structured result.
  return IPython.display.JSON({'result': ' '.join((a, b))})

output.register_callback('notebook.Concat', Concat)

# %%
# %%javascript
# (async function() {
#   const result = await google.colab.kernel.invokeFunction(
#     'notebook.Concat', // The callback name.
#     ['hello', 'world!'], // The arguments.
#     {}); // kwargs
#   const text = result.data['application/json'];
#   document.querySelector("#output-area").appendChild(document.createTextNode(text.result));
# })();

# %%
import IPython
from google.colab import output

display(IPython.display.HTML('''
    The items:
    <br><ol id="items"></ol>
    <button id='button'>Click to add</button>
    <script>
      document.querySelector('#button').onclick = () => {
        google.colab.kernel.invokeFunction('notebook.AddListItem', [], {});
      };
    </script>
    '''))

def add_list_item():
  # Use redirect_to_element to direct the elements which are being written.
  with output.redirect_to_element('#items'):
    # Use display to add items which will be persisted on notebook reload.
    display(IPython.display.HTML('<li> Another item</li>'))

output.register_callback('notebook.AddListItem', add_list_item)
# Out:
#     The items:
#     <br><ol id="items"></ol>
#     <button id='button'>Click to add</button>
#     <script>
#       document.querySelector('#button').onclick = () => {
#         google.colab.kernel.invokeFunction('notebook.AddListItem', [], {});
#       };
#     </script>
# <li> Another item</li>

# %%
import IPython
import uuid
from google.colab import output

class InvokeButton(object):
  def __init__(self, title, callback):
    self._title = title
    self._callback = callback

  def _repr_html_(self):
    callback_id = 'button-' + str(uuid.uuid4())
    output.register_callback(callback_id, self._callback)

    template = """<button id="{callback_id}">{title}</button>
        <script>
          document.querySelector("#{callback_id}").onclick = (e) => {{
            google.colab.kernel.invokeFunction('{callback_id}', [], {{}})
            e.preventDefault();
          }};
        </script>"""
    html = template.format(title=self._title, callback_id=callback_id)
    return html

def do_something():
  print('here')

InvokeButton('click me', do_something)
# Out:
# <button id="button-56070c2f-81ee-47f2-8899-a368c474104f">click me</button>
#         <script>
#           document.querySelector("#button-56070c2f-81ee-47f2-8899-a368c474104f").onclick = (e) => {
#             google.colab.kernel.invokeFunction('button-56070c2f-81ee-47f2-8899-a368c474104f', [], {})
#             e.preventDefault();
#           };
#         </script>
# here

# %%
import ipywidgets as widgets

slider = widgets.IntSlider(20, min=0, max=100)
slider
# Out:
# IntSlider(value=20)

# %%
import altair as alt
import ipywidgets as widgets
from vega_datasets import data

source = data.stocks()

stock_picker = widgets.SelectMultiple(
    options=source.symbol.unique(),
    value=list(source.symbol.unique()),
    description='Symbols')

# The value of symbols will come from the stock_picker.
@widgets.interact(symbols=stock_picker)
def render(symbols):
  selected = source[source.symbol.isin(list(symbols))]

  return alt.Chart(selected).mark_line().encode(
      x='date',
      y='price',
      color='symbol',
      strokeDash='symbol',
  )
# Out:
# interactive(children=(SelectMultiple(description='Symbols', index=(0, 1, 2, 3, 4), options=('MSFT', 'AMZN', 'I…

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
from IPython.display import Javascript

def target_func(comm, msg):
  # Only send the response if it's the data we are expecting.
  if msg['content']['data'] == 'the data':
    comm.send({
          'response': 'got comm open!',
        }, None, msg['buffers']);
get_ipython().kernel.comm_manager.register_target('comm_target', target_func)

Javascript('''
(async () => {
  const buffer = new Uint8Array(10);
  for (let i = 0; i < buffer.byteLength; ++i) {
    buffer[i] = i
  }
  const channel = await google.colab.kernel.comms.open('comm_target', 'the data', [buffer.buffer]);
  let success = false;
  for await (const message of channel.messages) {
    if (message.data.response == 'got comm open!') {
      const responseBuffer = new Uint8Array(message.buffers[0]);
      for (let i = 0; i < buffer.length; ++i) {
        if (responseBuffer[i] != buffer[i]) {
          console.error('comm buffer different at ' + i);
          return;
        }
      }
      // Close the channel once the expected message is received. This should
      // cause the messages iterator to complete and for the for-await loop to
      // end.
      channel.close();
    }
  }
  document.body.appendChild(document.createTextNode('done.'));
})()
''')

# %%
from IPython.display import Javascript
display(Javascript('''
(async () => {
  google.colab.kernel.comms.registerTarget('comms_testing', (comm, message) => {
    comm.send('this is the response', {buffers: message.buffers});
    document.body.appendChild(document.createTextNode('comm opened.'))
  });
})()'''))

from ipykernel import comm
buffer = b'hello world'
channel = comm.Comm(target_name='comms_testing', data={'foo': 1}, buffers=[buffer])

message = None
def handle_message(msg):
  global message
  message = msg

channel.on_msg(handle_message)

# %%
import time
import sys
from google.colab import output

print('Starting.')

with output.use_tags('some_outputs'):
  sys.stdout.write('working....\n')
  sys.stdout.flush();
  time.sleep(2)

  sys.stdout.write('still working...\n')
  sys.stdout.flush();
  time.sleep(2)

# Now clear the previous outputs.
output.clear(output_tags='some_outputs')
print('All done!')
# Out:
# Starting.
# All done!

# %%
import IPython

display(IPython.display.Javascript('''
  const promise = new Promise((resolve, reject) => {
    const script = document.createElement('script');
    script.src = 'data:,window.value = "hello world!"';
    script.onload = resolve;
    script.onerror = reject;
    document.head.appendChild(script);
  });
  // Pause subsequent outputs until the script has been loaded.
  google.colab.output.pauseOutputUntil(promise);
'''))

display(IPython.display.Javascript('''
    // Can immediately reference scripts loaded earlier since
    // output processing was blocked on them.
    document.body.appendChild(document.createTextNode(window.value));
'''))

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    _, img = cap.read()
    cv2_imshow('img', img)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = "/content/drive/MyDrive/Imagen/Sin título.jpg"
img = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=764x424 at 0x7F797CBFD690>

# %%
hist = cv2.calcHist([img], [0], None, [256], [0, 256])
#color gris
plt.plot(hist, color='gray')
#etiqueta del eje X
plt.xlabel('intensidad de iluminacion')
#etiqueta del eje X
plt.ylabel('cantidad de pixeles')
#muestra el histograma
plt.show()
#destruye las ventanas
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
#cv2.IMREAD_GRAYSCALE: carga la imagen
img = "/content/drive/MyDrive/Imagen/Sin título.jpg"
img = cv2.imread(img)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=764x424 at 0x7F798A3FFFA0>

# %%
#canal: b=azul , g=verde , r=azul
color = ('b','g','r')
#recorrido por cada canal
for i, c in enumerate(color):
  hist = cv2.calcHist([img], [i], None, [256], [0, 256])
  #color = c
  plt.plot(hist, color = c)
  #establece límites x de los ejes actuales
  plt.xlim([0,256])
#muestra el histograma
plt.show()
#destruye las ventanas
cv2.destroyAllWindows()
