# %% [markdown]
# <a href="https://colab.research.google.com/github/ISRAEL-MP/Practica0_Comentario_codigo_-limpio/blob/main/PROCESAMIENTO_DE_IM%C3%81GENES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Imagen/Sin título.jpg")

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
imagen=cv2.imread("/content/drive/MyDrive/Imagen/Sin título.jpg")
plt.imshow(imagen)

# %%
imagen=cv2.imread("/content/drive/MyDrive/Imagen/Sin título.jpg")
cv2.imwrite('deepgris.png',imagen)
# Out:
# True

# %%
import cv2
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/Imagen/Sin título.jpg"
img = cv2.imread(path)
plt.imshow(img)

# %%
import cv2
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/Imagen/Sin título.jpg"
img = cv2.imread(path)
im_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(im_rgb)

# %%
pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.22.4)

# %%
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

img = "/content/drive/MyDrive/Imagen/Sin título.jpg"
img = cv2.imread(img) # reads image
plt.imshow(img)

# %%
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/Imagen/Sin título.jpg"
img = cv2.imread(path)

import cv2
img = cv2.imread(path)
cv2_imshow(img)
cv2.imwrite('output.jpg',img)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=RGB size=764x424 at 0x7F9DBF237C10>
# -1

# %%
import cv2
imagen=cv2.imread("/content/drive/MyDrive/Imagen/Sin título.jpg")
cv2.imwrite('imagen.png', imagen)
# Out:
# True

# %%
resized_image = cv2.resize(img, (500,300))

# Colab users: 
cv2_imshow(resized_image)

# Jupyter Notebook users:
# cv2.imshow(“Penguins”, resized_image)
 
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=500x300 at 0x7F9DBEED28C0>

# %%
# Converting color image to grayscale image
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gris_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
yuv_img = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)
y,u,v = cv2.split(yuv_img)
cv2_imshow(gris_img)

# Y luminancia Y=0.2992+0.587G+0.114B
# Showing the converted image

# Colab users:
cv2_imshow(gray_img)
cv2_imshow(y)
cv2_imshow(u)

# Jupyter Notebook users:
# cv2_imshow("Converted Image",gray_img)

# waiting for key event
cv2.waitKey(0)

# destroying all windows
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=764x424 at 0x7F9DBF236860>
# <PIL.Image.Image image mode=L size=764x424 at 0x7F9DBEF29030>
# <PIL.Image.Image image mode=L size=764x424 at 0x7F9DBF236860>
# <PIL.Image.Image image mode=L size=764x424 at 0x7F9DBEF29030>

# %%
import cv2
import numpy as np
img = "/content/drive/MyDrive/Imagen/Sin título.jpg"
img = cv2.imread(img) # reads image
rows,cols = img.shape[:2]
M = np.float32([[1,0,210],[0,1,20]])
des = cv2.warpAffine(img,M,(cols,rows))
cv2_imshow(des)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=764x424 at 0x7F9DBF0C2200>

# %%
import cv2
import numpy as np
img = "/content/drive/MyDrive/Imagen/Sin título.jpg"
img = cv2.imread(img) # reads image
rows,cols = img.shape[:2]
M = cv2.getRotationMatrix2D((cols,rows),45,1)
dst = cv2.warpAffine(img,M,(cols,rows))
cv2_imshow(dst)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=RGB size=764x424 at 0x7F9DC238C040>
# -1

# %%
import cv2
camara = cv2.VideoCapture(0)
while True:
  ret,frame = camara.read()
  cv2_imshow(frame)
  if cv2.waitKey(1)&0xFF == ord('q'):break
camara.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-124-26b89308ae4f> in <cell line: 3>()
#       3 while True:
#       4   ret,frame = camara.read()
# ----> 5   cv2_imshow(frame)
#       6   if cv2.waitKey(1)&0xFF == ord('q'):break
#       7 camara.release()
#
# /usr/local/lib/python3.10/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       (N, M, 4) is an NxM BGRA color image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'
